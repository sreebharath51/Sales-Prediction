# %%
import os

# %%
pwd
# Out:
# 'C:\\Users\\reliance digital\\OneDrive\\Documents\\python\\jupyter'

# %%
os.chdir('C:\\Users\\reliance digital\\OneDrive\\Documents\\python\\jupyter')

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.linear_model import LinearRegression

# %%
data=pd.read_csv("train2.csv")
x=data.drop(columns=['Item_Outlet_Sales'])
y=data['Item_Outlet_Sales']
data
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15        9.300          Low Fat         0.016047
# 1              DRC01        5.920          Regular         0.019278
# 2              FDN15       17.500          Low Fat         0.016760
# 3              FDX07       19.200          Regular         0.000000
# 4              NCD19        8.930          Low Fat         0.000000
# ...              ...          ...              ...              ...
# 8518           FDF22        6.865          Low Fat         0.056783
# 8519           FDS36        8.380          Regular         0.046982
# 8520           NCJ29       10.600          Low Fat         0.035186
# 8521           FDN46        7.210          Regular         0.145221
# 8522           DRG01       14.800          Low Fat         0.044878
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy  249.8092            OUT049
# ...

# %%
x=x.fillna(0)
#converting string into numeric using  frequency encoding method
#first we make a dictonary that maps each label to the count
#and we replace labels in the input data set x
Item_Identifier=x.Item_Identifier.value_counts().to_dict()
x.Item_Identifier=x.Item_Identifier.map(Item_Identifier)
Item_Fat_Content=x.Item_Fat_Content.value_counts().to_dict()
x.Item_Fat_Content=x.Item_Fat_Content.map(Item_Fat_Content)
Item_Type=x.Item_Type.value_counts().to_dict()
x.Item_Type=x.Item_Type.map(Item_Type)
Outlet_Identifier=x.Outlet_Identifier.value_counts().to_dict()
x.Outlet_Identifier=x.Outlet_Identifier.map(Outlet_Identifier)
Outlet_Size=x.Outlet_Size.value_counts().to_dict()
x.Outlet_Size=x.Outlet_Size.map(Outlet_Size)
Outlet_Location_Type=x.Outlet_Location_Type.value_counts().to_dict()
x.Outlet_Location_Type=x.Outlet_Location_Type.map(Outlet_Location_Type)
Outlet_Type=x.Outlet_Type.value_counts().to_dict()
x.Outlet_Type=x.Outlet_Type.map(Outlet_Type)
x
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                   8        9.300              5089         0.016047
# 1                   6        5.920              2889         0.019278
# 2                   7       17.500              5089         0.016760
# 3                   6       19.200              2889         0.000000
# 4                   6        8.930              5089         0.000000
# ...               ...          ...               ...              ...
# 8518                8        6.865              5089         0.056783
# 8519                6        8.380              2889         0.046982
# 8520                6       10.600              5089         0.035186
# 8521                6        7.210              2889         0.145221
# 8522                5       14.800              5089         0.044878
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

print('Mean of Target Variable : ',y_train.mean())

# predict the target on the test dataset
predict_train = [y_train.mean() for i in range(y_train.shape[0])]
 
# Root Mean Squared Error on training dataset
rmse_train = mean_squared_error(y_train,predict_train)**(0.5)
print('\nMSE on train dataset : ', rmse_train)
# Out:
# Mean of Target Variable :  2180.091984951604
#
# MSE on train dataset :  1700.5729722766343

# %%
x_train, x_val, y_train, y_val = train_test_split(x,y, test_size =0.3)

lreg= LinearRegression()
# training a linear regression model on train
lreg.fit(x_train,y_train)

# predicting on val
pred_val = lreg.predict(x_val)

# calculating mse
mse = np.mean((pred_val - y_val)**2)
mse
# Out:
# 1371472.920762143

# %%
lreg.score(x_val,y_val)
# Out:
# 0.5559829858035246

# %%
from sklearn.linear_model import Ridge

## training the model

ridgeReg = Ridge(alpha=0.05, normalize=True)

ridgeReg.fit(x_train,y_train)

pred = ridgeReg.predict(x_val)

mse = np.mean((pred_val - y_val)**2)

# %%
mse
# Out:
# 1371472.920762143

# %%
from sklearn.linear_model import Lasso

lassoReg = Lasso(alpha=0.3, normalize=True)

lassoReg.fit(x_train,y_train)

pred = lassoReg.predict(x_val)

# calculating mse

mse = np.mean((pred_val - y_val)**2)

lassoReg.score(x_val,y_val)
# Out:
# 0.5447968261968755

# %%
mse
# Out:
# 1371472.920762143

# %%
#importing test dataset
data2=pd.read_csv("test2.csv")
data2
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDW58       20.750          Low Fat         0.007565
# 1              FDW14        8.300              reg         0.038428
# 2              NCN55       14.600          Low Fat         0.099575
# 3              FDQ58        7.315          Low Fat         0.015388
# 4              FDY38          NaN          Regular         0.118599
# ...              ...          ...              ...              ...
# 5676           FDB58       10.500          Regular         0.013496
# 5677           FDD47        7.600          Regular         0.142991
# 5678           NCO17       10.000          Low Fat         0.073529
# 5679           FDJ26       15.300          Regular         0.000000
# 5680           FDU37        9.500          Regular         0.104720
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0            Snack Foods  107.8622            OUT049
# ...

# %%
data2=data2.fillna(0)
#converting string into numeric using  frequency encoding method
#first we make a dictonary that maps each label to the count
#and we replace labels in the input data set data2
Item_Identifier=data2.Item_Identifier.value_counts().to_dict()
data2.Item_Identifier=data2.Item_Identifier.map(Item_Identifier)
Item_Fat_Content=data2.Item_Fat_Content.value_counts().to_dict()
data2.Item_Fat_Content=data2.Item_Fat_Content.map(Item_Fat_Content)
Item_Type=data2.Item_Type.value_counts().to_dict()
data2.Item_Type=data2.Item_Type.map(Item_Type)
Outlet_Identifier=data2.Outlet_Identifier.value_counts().to_dict()
data2.Outlet_Identifier=data2.Outlet_Identifier.map(Outlet_Identifier)
Outlet_Size=data2.Outlet_Size.value_counts().to_dict()
data2.Outlet_Size=data2.Outlet_Size.map(Outlet_Size)
Outlet_Location_Type=data2.Outlet_Location_Type.value_counts().to_dict()
data2.Outlet_Location_Type=data2.Outlet_Location_Type.map(Outlet_Location_Type)
Outlet_Type=data2.Outlet_Type.value_counts().to_dict()
data2.Outlet_Type=data2.Outlet_Type.map(Outlet_Type)
data2
# Out:
#       Item_Identifier  Item_Weight  Item_Fat_Content  Item_Visibility  \
# 0                   7       20.750              3396         0.007565
# 1                   6        8.300                78         0.038428
# 2                   4       14.600              3396         0.099575
# 3                   3        7.315              3396         0.015388
# 4                   4        0.000              1935         0.118599
# ...               ...          ...               ...              ...
# 5676                3       10.500              1935         0.013496
# 5677                4        7.600              1935         0.142991
# 5678                2       10.000              3396         0.073529
# 5679                5       15.300              1935         0.000000
# 5680                4        9.500              1935         0.104720
#
#       Item_Type  Item_MRP  Outlet_Identifier  Outlet_Establishment_Year  \
# ...

# %%
prediction=lreg.predict(data2)
prediction
# Out:
# array([-1450.88459593, -1977.20291281,  -714.84159668, ...,
#        -1340.52780732,  -142.71483918, -1895.8305788 ])

# %%
#converting array into dataframe
b=pd.DataFrame(prediction)
b
# Out:
#                 0
# 0    -1450.884596
# 1    -1977.202913
# 2     -714.841597
# 3    -1012.638270
# 4     1578.505472
# ...           ...
# 5676  -937.272541
# 5677  -799.986007
# 5678 -1340.527807
# 5679  -142.714839
# 5680 -1895.830579
#
# [5681 rows x 1 columns]

# %%
k=pd.DataFrame(prediction)
#selecting the Item_Identifier from the input data set
j=data2['Item_Identifier']
#merging the Item_Identifier column and prediction output then making a new data frame.
h=pd.concat([j,k],axis=1)
h.columns={'Item_Identifier','Item_Outlet_Sales'}
h
# Out:
#       Item_Identifier  Item_Outlet_Sales
# 0                   7       -1450.884596
# 1                   6       -1977.202913
# 2                   4        -714.841597
# 3                   3       -1012.638270
# 4                   4        1578.505472
# ...               ...                ...
# 5676                3        -937.272541
# 5677                4        -799.986007
# 5678                2       -1340.527807
# 5679                5        -142.714839
# 5680                4       -1895.830579
#
# [5681 rows x 2 columns]

# %%
h.to_csv('sample_submission1.csv',index=False)
